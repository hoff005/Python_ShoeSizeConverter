# %%
# Female and Male Shoe Size Converter - Regions: US/Canada, UK, Euro and Australia/NZ
# Returns shoe sizes of other regions when: gender, region and person's regional shoe size provided 

gender = input("Please enter either: 'female' or 'male' " )
region = input("Please enter your region code: (US, UK, EU, AU or NZ): ")
shoe_size = input("Please enter your correct shoe size: ")

### Inputs of female and her shoe size

# US Female to other regions conversion
if gender in ["female"] and region == "US" and shoe_size == "5":
        print("{}Your size in other regions is: UK = 2.5 Euro = 35 Australia/NZ = 3.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "US" and shoe_size == "5.5":
                print("{}Your size in other regions is: UK = 3 Euro = 35.5 Australia/NZ = 4{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "US" and shoe_size == "6":
                print("{}Your size in other regions is: UK = 3.5 Euro = 36 Australia/NZ = 4.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "US" and shoe_size == "6.5":
                print("{}Your size in other regions is: UK = 4 Euro = 37 Australia/NZ = 5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "US" and shoe_size == "7":
                print("{}Your size in other regions is: UK = 4.5 Euro = 37.5 Australia/NZ = 5.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "US" and shoe_size == "7.5":
                print("{}Your size in other regions is: UK = 5 Euro = 38 Australia/NZ = 6{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "US" and shoe_size == "8":
                print("{}Your size in other regions is: UK = 5.5 Euro = 38.5 Australia/NZ = 6.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "US" and shoe_size == "8.5":
                print("{}Your size in other regions is: UK = 6 Euro = 39 Australia/NZ = 7{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "US" and shoe_size == "9":
                print("{}Your size in other regions is: UK = 6.5 Euro = 40 Australia/NZ = 7.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "US" and shoe_size == "9.5":
                print("{}Your size in other regions is: UK = 7 Euro = 41 Australia/NZ = 8{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "US" and shoe_size == "10":
                print("{}Your size in other regions is: UK = 7.5 Euro = 42 Australia/NZ = 8.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "US" and shoe_size == "10.5":
                print("{}Your size in other regions is: UK = 8 Euro = 43 Australia/NZ = 9{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "US" and shoe_size == "12":
                print("{}Your size in other regions is: UK = 9.5 Euro = 44 Australia/NZ = 10.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "US" and shoe_size == "13":
                print("{}Your size in other regions is: UK = 10.5 Euro = 45 Australia/NZ = 11.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "US" and shoe_size == "14":
                print("{}Your size in other regions is: UK = 11.5 Euro = 46.5 Australia/NZ = 12.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "US" and shoe_size == "15.5":
                print("{}Your size in other regions is: UK = 13 Euro = 48.5 Australia/NZ = 14{}".format('\033[1m', '\033[0m'))
    
# UK Female to other regions conversion
elif gender in ["female"] and region == "UK" and shoe_size == "2.5":
                print("{}Your size in other regions is: US = 5 Euro = 35 Australia/NZ = 3.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "UK" and shoe_size == "3":
                print("{}Your size in other regions is: US = 5.5 Euro = 35.5 Australia/NZ = 4{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "UK" and shoe_size == "3.5":
                print("{}Your size in other regions is: US = 6 Euro = 36 Australia/NZ = 4.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "UK" and shoe_size == "4":
                print("{}Your size in other regions is: US = 6.5 Euro = 37 Australia/NZ = 5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "UK" and shoe_size == "4.5":
                print("{}Your size in other regions is: US = 7 Euro = 37.5 Australia/NZ = 5.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "UK" and shoe_size == "5":
                print("{}Your size in other regions is: US = 7.5 Euro = 38 Australia/NZ = 6{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "UK" and shoe_size == "5.5":
                print("{}Your size in other regions is: US = 8 Euro = 38.5 Australia/NZ = 6.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "UK" and shoe_size == "6":
                print("{}Your size in other regions is: US = 8.5 Euro = 39 Australia/NZ = 7{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "UK" and shoe_size == "6.5":
                print("{}Your size in other regions is: US = 9 Euro = 40 Australia/NZ = 7.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "UK" and shoe_size == "7":
                print("{}Your size in other regions is: US = 9.5 Euro = 41 Australia/NZ = 8{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "UK" and shoe_size == "7.5":
                print("{}Your size in other regions is: US = 10 Euro = 42 Australia/NZ = 8.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "UK" and shoe_size == "8":
                print("{}Your size in other regions is: US = 10.5 Euro = 43 Australia/NZ = 9{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "UK" and shoe_size == "9.5":
                print("{}Your size in other regions is: US = 12 Euro = 44 Australia/NZ = 10.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "UK" and shoe_size == "10.5":
                print("{}Your size in other regions is: US = 13 Euro = 45 Australia/NZ = 11.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "UK" and shoe_size == "11.5":
                print("{}Your size in other regions is: US = 14 Euro = 46.5 Australia/NZ = 12.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "UK" and shoe_size == "13":
                print("{}Your size in other regions is: US = 15.5 Euro = 48.5 Australia/NZ = 14{}".format('\033[1m', '\033[0m'))

# EU Female to other regions conversion
elif gender in ["female"] and region == "EU" and shoe_size == "35":
                print("{}Your size in other regions is: US = 5 UK = 2.5 Australia/NZ = 3.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "EU" and shoe_size == "35.5":
                print("{}Your size in other regions is: US = 5.5 UK = 3 Australia/NZ = 4{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "EU" and shoe_size == "36":
                print("{}Your size in other regions is: US = 6 UK = 3.5 Australia/NZ = 4.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "EU" and shoe_size == "37":
                print("{}Your size in other regions is: US = 6.5 UK = 4 Australia/NZ = 5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "EU" and shoe_size == "37.5":
                print("{}Your size in other regions is: US = 7 UK = 4.5 Australia/NZ = 5.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "EU" and shoe_size == "38":
                print("{}Your size in other regions is: US = 7.5 UK = 5 Australia/NZ = 6{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "EU" and shoe_size == "38.5":
                print("{}Your size in other regions is: US = 8 UK = 5.5 Australia/NZ = 6.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "EU" and shoe_size == "39":
                print("{}Your size in other regions is: US = 8.5 UK = 6 Australia/NZ = 7{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "EU" and shoe_size == "40":
                print("{}Your size in other regions is: US = 9 UK = 6.5 Australia/NZ = 7.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "EU" and shoe_size == "41":
                print("{}Your size in other regions is: US = 9.5 UK = 7 Australia/NZ = 8{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "EU" and shoe_size == "42":
                print("{}Your size in other regions is: US = 10 UK = 7.5 Australia/NZ = 8.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "EU" and shoe_size == "43":
                print("{}Your size in other regions is: US = 10.5 UK = 8 Australia/NZ = 9{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "EU" and shoe_size == "44":
                print("{}Your size in other regions is: US = 12 UK = 9.5 Australia/NZ = 10.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "EU" and shoe_size == "45":
                print("{}Your size in other regions is: US = 13 UK = 10.5 Australia/NZ = 11.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "EU" and shoe_size == "46.5":
                print("{}Your size in other regions is: US = 14 UK = 11.5 Australia/NZ = 12.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region == "EU" and shoe_size == "48.5":
                print("{}Your size in other regions is: US = 15.5 UK = 13 Australia/NZ = 14{}".format('\033[1m', '\033[0m'))

# AU/NZ Female to other regions conversion
elif gender in ["female"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "3.5":
                print("{}Your size in other regions is: US = 5 UK = 2.5 Euro = 35{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "4":
                print("{}Your size in other regions is: US = 5.5 UK = 3 Euro = 35.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "4.5":
                print("{}Your size in other regions is: US = 6 UK = 3.5 Euro = 36{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "5":
                print("{}Your size in other regions is: US = 6.5 UK = 4 Euro = 37{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "5.5":
                print("{}Your size in other regions is: US = 7 UK = 4.5 Euro = 37.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "6":
                print("{}Your size in other regions is: US = 7.5 UK = 5 Euro = 38{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "6.5":
                print("{}Your size in other regions is: US = 8 UK = 5.5 Euro = 38.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "7":
                print("{}Your size in other regions is: US = 8.5 UK = 6 Euro = 39{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "7.5":
                print("{}Your size in other regions is: US = 9 UK = 6.5 Euro = 40{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "8":
                print("{}Your size in other regions is: US = 9.5 UK = 7 Euro = 41{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "8.5":
                print("{}Your size in other regions is: US = 10 UK = 7.5 Euro = 42{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "9":
                print("{}Your size in other regions is: US = 10.5 UK = 8 Euro = 43{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "10.5":
                print("{}Your size in other regions is: US = 12 UK = 9.5 Euro = 44{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "11.5":
                print("{}Your size in other regions is: US = 13 UK = 10.5 Euro = 45{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "12.5":
                print("{}Your size in other regions is: US = 14 UK = 11.5 Euro = 46.5{}".format('\033[1m', '\033[0m'))
elif gender in ["female"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "14":
                print("{}Your size in other regions is: US = 15.5 UK = 13 Euro = 48.5{}".format('\033[1m', '\033[0m'))

### Inputs of male and his shoe size 

# US Male to other regions conversion
elif gender in ["male"] and region == "US" and shoe_size == "3.5":
                print("{}Your size in other regions is: UK = 3 Euro = 35 Australia/NZ = 3{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "4":
                print("{}Your size in other regions is: UK = 3.5 Euro = 35.5 Australia/NZ = 3.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "4.5":
                print("{}Your size in other regions is: UK = 4 Euro = 36 Australia/NZ = 4{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "5":
                print("{}Your size in other regions is: UK = 4.5 Euro = 37 Australia/NZ = 4.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "5.5":
                print("{}Your size in other regions is: UK = 5 Euro = 37.5 Australia/NZ = 5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "6":
                print("{}Your size in other regions is: UK = 5.5 Euro = 38 Australia/NZ = 5.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "6.5":
                print("{}Your size in other regions is: UK = 6 Euro = 38.5 Australia/NZ = 6{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "7":
                print("{}Your size in other regions is: UK = 6.5 Euro = 39 Australia/NZ = 6.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "7.5":
                print("{}Your size in other regions is: UK = 7 Euro = 40 Australia/NZ = 7{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "8":
                print("{}Your size in other regions is: UK = 7.5 Euro = 41 Australia/NZ = 7.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "8.5":
                print("{}Your size in other regions is: UK = 8 Euro = 42 Australia/NZ = 8{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "9":
                print("{}Your size in other regions is: UK = 8.5 Euro = 43 Australia/NZ = 8.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "9.5":
                print("{}Your size in other regions is: UK = 9 Euro = 43.5 Australia/NZ = 9{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "10":
                print("{}Your size in other regions is: UK = 9.5 Euro = 44 Australia/NZ = 9.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "10.5":
                print("{}Your size in other regions is: UK = 10 Euro = 44.5 Australia/NZ = 10{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "11":
                print("{}Your size in other regions is: UK = 10.5 Euro = 45 Australia/NZ = 10.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "11.5":
                print("{}Your size in other regions is: UK = 11 Euro = 45.5 Australia/NZ = 11{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "12":
                print("{}Your size in other regions is: UK = 11.5 Euro = 46 Australia/NZ = 11.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "12.5":
                print("{}Your size in other regions is: UK = 12 Euro = 46.5 Australia/NZ = 12{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "13":
                print("{}Your size in other regions is: UK = 12.5 Euro = 47 Australia/NZ = 12.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "US" and shoe_size == "13.5":
                print("{}Your size in other regions is: UK = 13 Euro = 47.5 Australia/NZ = 13{}".format('\033[1m', '\033[0m'))

# UK Male to other regions conversion
elif gender in ["male"] and region == "UK" and shoe_size == "3":
                print("{}Your size in other regions is: US = 3.5 Euro = 35 Australia/NZ = 3{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "3.5":
                print("{}Your size in other regions is: US = 4 Euro = 35.5 Australia/NZ = 3.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "4":
                print("{}Your size in other regions is: US = 4.5 Euro = 36 Australia/NZ = 4{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "4.5":
                print("{}Your size in other regions is: US = 5 Euro = 37 Australia/NZ = 4.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "5":
                print("{}Your size in other regions is: US = 5.5 Euro = 37.5 Australia/NZ = 5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "5.5":
                print("{}Your size in other regions is: US = 6 Euro = 38 Australia/NZ = 5.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "6":
                print("{}Your size in other regions is: US = 6.5 Euro = 38.5 Australia/NZ = 6{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "6.5":
                print("{}Your size in other regions is: US = 7 Euro = 39 Australia/NZ = 6.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "7":
                print("{}Your size in other regions is: US = 7.5 Euro = 40 Australia/NZ = 7{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "7.5":
                print("{}Your size in other regions is: US = 8 Euro = 41 Australia/NZ = 7.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "8":
                print("{}Your size in other regions is: US = 8.5 Euro = 42 Australia/NZ = 8{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "8.5":
                print("{}Your size in other regions is: US = 9 Euro = 43 Australia/NZ = 8.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "9":
                print("{}Your size in other regions is: US = 9.5 Euro = 43.5 Australia/NZ = 9{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "9.5":
                print("{}Your size in other regions is: US = 10 Euro = 44 Australia/NZ = 9.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "10":
                print("{}Your size in other regions is: US = 10.5 Euro = 44.5 Australia/NZ = 10{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "10.5":
                print("{}Your size in other regions is: US = 11 Euro = 45 Australia/NZ = 10.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "11":
                print("{}Your size in other regions is: US = 11.5 Euro = 45.5 Australia/NZ = 11{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "11.5":
                print("{}Your size in other regions is: US = 12 Euro = 46 Australia/NZ = 11.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "12":
                print("{}Your size in other regions is: US = 12.5 Euro = 46.5 Australia/NZ = 12{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "12.5":
                print("{}Your size in other regions is: US = 13 Euro = 47 Australia/NZ = 12.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "UK" and shoe_size == "13":
                print("{}Your size in other regions is: US = 13.5 Euro = 47.5 Australia/NZ = 13{}".format('\033[1m', '\033[0m'))

# EU Male to other regions conversion
elif gender in ["male"] and region == "EU" and shoe_size == "35":
                print("{}Your size in other regions is: US = 3.5 UK = 35 Australia/NZ = 3{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "35.5":
                print("{}Your size in other regions is: US = 4 UK = 35.5 Australia/NZ = 3.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "36":
                print("{}Your size in other regions is: US = 4.5 UK = 36 Australia/NZ = 4{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "37":
                print("{}Your size in other regions is: US = 5 UK = 37 Australia/NZ = 4.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "37.5":
                print("{}Your size in other regions is: US = 5.5 UK = 37.5 Australia/NZ = 5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "38":
                print("{}Your size in other regions is: US = 6 UK = 38 Australia/NZ = 5.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "38.5":
                print("{}Your size in other regions is: US = 6.5 UK = 38.5 Australia/NZ = 6{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "39":
                print("{}Your size in other regions is: US = 7 UK = 39 Australia/NZ = 6.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "40":
                print("{}Your size in other regions is: US = 7.5 UK = 40 Australia/NZ = 7{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "41":
                print("{}Your size in other regions is: US = 8 UK = 41 Australia/NZ = 7.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "42":
                print("{}Your size in other regions is: US = 8.5 UK = 42 Australia/NZ = 8{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "43":
                print("{}Your size in other regions is: US = 9 UK = 43 Australia/NZ = 8.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "43.5":
                print("{}Your size in other regions is: US = 9.5 UK = 43.5 Australia/NZ = 9{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "44":
                print("{}Your size in other regions is: US = 10 UK = 44 Australia/NZ = 9.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "44.5":
                print("{}Your size in other regions is: US = 10.5 UK = 44.5 Australia/NZ = 10{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "45":
                print("{}Your size in other regions is: US = 11 UK = 45 Australia/NZ = 10.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "45.5":
                print("{}Your size in other regions is: US = 11.5 UK = 45.5 Australia/NZ = 11{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "46":
                print("{}Your size in other regions is: US = 12 UK = 46 Australia/NZ = 11.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "46.5":
                print("{}Your size in other regions is: US = 12.5 UK = 46.5 Australia/NZ = 12{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "47":
                print("{}Your size in other regions is: US = 13 UK = 47 Australia/NZ = 12.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region == "EU" and shoe_size == "47.5":
                print("{}Your size in other regions is: US = 13.5 UK = 47.5 Australia/NZ = 13{}".format('\033[1m', '\033[0m'))

# AU/NZ Male to other regions conversion
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "3":
                print("{}Your size in other regions is: US = 3.5 UK = 3 Euro = 35{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "3.5":
                print("{}Your size in other regions is: US = 4 UK = 3.5 Euro = 35.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "4":
                print("{}Your size in other regions is: US = 4.5 UK = 4 Euro = 36{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "4.5":
                print("{}Your size in other regions is: US = 5 UK = 4.5 Euro = 37{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "5":
                print("{}Your size in other regions is: US = 5.5 UK = 5 Euro = 37.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "5.5":
                print("{}Your size in other regions is: US = 6 UK = 5.5 Euro = 38{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "6":
                print("{}Your size in other regions is: US = 6.5 UK = 6 Euro = 38.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "6.5":
                print("{}Your size in other regions is: US = 7 UK = 6.5 Euro = 39{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "7":
                print("{}Your size in other regions is: US = 7.5 UK = 7 Euro = 40{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "7.5":
                print("{}Your size in other regions is: US = 8 UK = 7.5 Euro = 41{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "8":
                print("{}Your size in other regions is: US = 8.5 UK = 8 Euro = 42{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "8.5":
                print("{}Your size in other regions is: US = 9 UK = 8.5 Euro = 43{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "9":
                print("{}Your size in other regions is: US = 9.5 UK = 9 Euro = 44{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "9.5":
                print("{}Your size in other regions is: US = 10 UK = 9.5 Euro = 44.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "10":
                print("{}Your size in other regions is: US = 10.5 UK = 10 Euro = 44.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "10.5":
                print("{}Your size in other regions is: US = 11 UK = 10.5 Euro = 45{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "11":
                print("{}Your size in other regions is: US = 11.5 UK = 11 Euro = 45.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "11.5":
                print("{}Your size in other regions is: US = 12 UK = 11.5 Euro = 46{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "12":
                print("{}Your size in other regions is: US = 12.5 UK = 12 Euro = 46.5{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "12.5":
                print("{}Your size in other regions is: US = 13 UK = 12.5 Euro = 47{}".format('\033[1m', '\033[0m'))
elif gender in ["male"] and region in ["AU", "NZ", "au", "nz", "Australia", "australia", "New Zealand", "new zealand"] and shoe_size == "13":
                print("{}Your size in other regions is: US = 13.5 UK = 13 Euro = 47.5{}".format('\033[1m', '\033[0m'))
else:
    print("Please check your input and enter: [either 'female' or 'male' and a valid shoe size]")
